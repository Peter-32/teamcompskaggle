# %%
import pandas as pd

# %%
role = {"Yone": 11,
"Katarina": 11,
"Akali": 11,
"Kha'Zix": 11,
"Pyke": 11,
"Fizz": 11,
"Diana": 11,
"Rengar": 11,
"Shaco": 11,
"Ekko": 11,
"Kassadin": 11,
"Qiyana": 11,
"Zed": 11,
"Evelynn": 11,
"Nocturne": 11,
"Talon": 11,
"Viktor": 10,
"Rumble": 10,
"Anivia": 10,
"Cassiopeia": 10,
"Ryze": 10,
"Swain": 10,
"Karthus": 10,
"Taliyah": 10,
"Vladimir": 10,
"Aurelion_Sol": 10,
"Malzahar": 10,
"Teemo": 10,
"Viego": 9,
"Jax": 9,
"Master_Yi": 9,
"Tryndamere": 9,
"Kayn": 9,
"Gwen": 9,
"Riven": 9,
"Kled": 9,
"Fiora": 9,
"Lillia": 9,
"Yasuo": 9,
"Gnar": 9,
"Gangplank": 9,
"Bard": 8,
"Jhin": 8,
"Blitzcrank": 8,
"Rakan": 8,
"Thresh": 8,
"Ivern": 8,
"Morgana": 8,
"Zyra": 8,
"Cho'Gath": 7,
"Zilean": 7,
"Braum": 7,
"Poppy": 7,
"Shen": 7,
"Tahm_Kench": 7,
"Galio": 7,
"Ziggs": 6,
"Xerath": 6,
"Lux": 6,
"Varus": 6,
"Vel'Koz": 6,
"Jayce": 6,
"Orianna": 6,
"Sylas": 6,
"Lissandra": 6,
"Syndra": 6,
"Brand": 6,
"Veigar": 6,
"Zoe": 6,
"Neeko": 6,
"Annie": 6,
"Karma": 6,
"LeBlanc": 6,
"Twisted_Fate": 6,
"Ahri": 6,
"Seraphine": 6,
"Azir": 6,
"Heimerdinger": 6,
"Nidalee": 6,
"Kennen": 6,
"Akshan": 5,
"Caitlyn": 5,
"Kai'Sa": 5,
"Twitch": 5,
"Tristana": 5,
"Xayah": 5,
"Kog'Maw": 5,
"Jinx": 5,
"Miss_Fortune": 5,
"Lucian": 5,
"Kalista": 5,
"Aphelios": 5,
"Vayne": 5,
"Kindred": 5,
"Corki": 5,
"Ashe": 5,
"Ezreal": 5,
"Samira": 5,
"Sivir": 5,
"Draven": 5,
"Quinn": 5,
"Graves": 5,
"Kayle": 5,
"Lulu": 4,
"Soraka": 4,
"Yuumi": 4,
"Senna": 4,
"Sona": 4,
"Nami": 4,
"Taric": 4,
"Janna": 4,
"Darius": 3,
"Sett": 3,
"Udyr": 3,
"Dr._Mundo": 3,
"Yorick": 3,
"Illaoi": 3,
"Aatrox": 3,
"Shyvana": 3,
"Urgot": 3,
"Trundle": 3,
"Nasus": 3,
"Volibear": 3,
"Mordekaiser": 3,
"Garen": 3,
"Pantheon": 2,
"Irelia": 2,
"Camille": 2,
"Warwick": 2,
"Hecarim": 2,
"Olaf": 2,
"Skarner": 2,
"Vi": 2,
"Rek'Sai": 2,
"Elise": 2,
"Xin_Zhao": 2,
"Renekton": 2,
"Wukong": 2,
"Jarvan_IV": 2,
"Lee_Sin": 2,
"Fiddlesticks": 2,
"Singed": 1,
"Sion": 1,
"Alistar": 1,
"Amumu": 1,
"Nautilus": 1,
"Maokai": 1,
"Ornn": 1,
"Gragas": 1,
"Rammus": 1,
"Malphite": 1,
"Zac": 1,
"Rell": 1,
"Leona": 1,
"Sejuani": 1,
"Nunu_&_Willump": 1,}

# %%
source = pd.read_csv("../data/matches.csv").drop(["Unnamed: 0"], axis='columns').drop_duplicates()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 source = pd.read_csv("../data/matches.csv").drop(["Unnamed: 0"], axis='columns').drop_duplicates()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
# ...

# %%
t1 = [x for x in source.columns[:-2] if ".1" not in x]
t2 = [x for x in source.columns[:-2] if ".1" in x]

# %%
from tqdm import tqdm

# %%
# ones = []
# twos = []
# threes = []
# fours = []
# fives = []
# sixes = []
# sevens = []
# eights = []
# nines = []
# tens = []
# elevens = []
# ones_b = []
# twos_b = []
# threes_b = []
# fours_b = []
# fives_b = []
# sixes_b = []
# sevens_b = []
# eights_b = []
# nines_b = []
# tens_b = []
# elevens_b = []
# results = []
# for index, row in tqdm(source.iterrows()):
#     one = 0
#     two = 0
#     three = 0
#     four = 0
#     five = 0
#     six = 0
#     seven = 0
#     eight = 0
#     nine = 0
#     ten = 0
#     eleven = 0
#     one_b = 0
#     two_b = 0
#     three_b = 0
#     four_b = 0
#     five_b = 0
#     six_b = 0
#     seven_b = 0
#     eight_b = 0
#     nine_b = 0
#     ten_b = 0
#     eleven_b = 0
#     t1_list = []
    
#     for column in t1:
#         if row[column] == 1.0:
#             t1_list.append(column)
#     t2_list = []
#     for column in t2:
#         if row[column] == 1.0:
#             t2_list.append(column.replace(".1", ""))    
#     result = 1 if row['Team1'] == 1.0 else 0
    
#     for x in t1_list:
#         x = x.replace(" ", "_")
#         if role[x] == 1:
#             one += 1
#         elif role[x] == 2:
#             two += 1
#         elif role[x] == 3:
#             three += 1
#         elif role[x] == 4:
#             four += 1
#         elif role[x] == 5:
#             five += 1
#         elif role[x] == 6:
#             six += 1
#         elif role[x] == 7:
#             seven += 1
#         elif role[x] == 8:
#             eight += 1
#         elif role[x] == 9:
#             nine += 1
#         elif role[x] == 10:
#             ten += 1
#         elif role[x] == 11:
#             eleven += 1
#     for x in t2_list:
#         x = x.replace(" ", "_")
#         if role[x] == 1:
#             one_b += 1
#         elif role[x] == 2:
#             two_b += 1
#         elif role[x] == 3:
#             three_b += 1
#         elif role[x] == 4:
#             four_b += 1
#         elif role[x] == 5:
#             five_b += 1
#         elif role[x] == 6:
#             six_b += 1
#         elif role[x] == 7:
#             seven_b += 1
#         elif role[x] == 8:
#             eight_b += 1
#         elif role[x] == 9:
#             nine_b += 1
#         elif role[x] == 10:
#             ten_b += 1
#         elif role[x] == 11:
#             eleven_b += 1
            
#     ones.append(one)
#     twos.append(two)
#     threes.append(three)
#     fours.append(four)
#     fives.append(five)
#     sixes.append(six)
#     sevens.append(seven)
#     eights.append(eight)
#     nines.append(nine)
#     tens.append(ten)
#     elevens.append(eleven)
#     ones_b.append(one_b)
#     twos_b.append(two_b)
#     threes_b.append(three_b)
#     fours_b.append(four_b)
#     fives_b.append(five_b)
#     sixes_b.append(six_b)
#     sevens_b.append(seven_b)
#     eights_b.append(eight_b)
#     nines_b.append(nine_b)
#     tens_b.append(ten_b)
#     elevens_b.append(eleven_b)  
#     results.append(result)
    
# df = pd.DataFrame()
# df['one'] = ones
# df['two'] = twos
# df['three'] = threes
# df['four'] = fours
# df['five'] = fives
# df['six'] = sixes
# df['seven'] = sevens
# df['eight'] = eights
# df['nine'] = nines
# df['ten'] = tens
# df['eleven'] = elevens
# df['one_b'] = ones_b
# df['two_b'] = twos_b
# df['three_b'] = threes_b
# df['four_b'] = fours_b
# df['five_b'] = fives_b
# df['six_b'] = sixes_b
# df['seven_b'] = sevens_b
# df['eight_b'] = eights_b
# df['nine_b'] = nines_b
# df['ten_b'] = tens_b
# df['eleven_b'] = elevens_b
# df['results'] = results
# df.rename(columns={'results': 'target'}, inplace=True)
# df

df = source
df.drop(['Team2'], axis='columns', inplace=True)
df.rename(columns={'Team1': 'target'}, inplace=True)
df

# %%
df['target'].value_counts(normalize=True)

# %%
from numpy.random import seed
from sklearn.model_selection import train_test_split
seed(32)
split_size = 0.4 if df.shape[0] < 100000 else 40000/df.shape[0]
train, temp = train_test_split(df, test_size=split_size)
dev, test = train_test_split(temp, test_size=0.50)
X = df.drop(['target'], axis=1)
y = df[['target']]
X_train = train.drop(['target'], axis=1)
y_train = train[['target']]
X_dev = dev.drop(['target'], axis=1)
y_dev = dev[['target']]
X_test = test.drop(['target'], axis=1)
y_test = test[['target']]
train.shape, dev.shape, test.shape, train.target.value_counts(normalize=True)

# %%
from sklearn.metrics import accuracy_score

def get_score():
    seed(32)
    model.fit(X_train, y_train)
    accuracy_train = accuracy_score(y_train, model.predict(X_train))
    accuracy_dev = accuracy_score(y_dev, model.predict(X_dev))
    print("Train Score:", accuracy_train)
    print("Dev Score:", accuracy_dev)
accuracy_baseline1 = accuracy_score(y_dev, [0]*X_dev.shape[0])
accuracy_baseline2 = accuracy_score(y_dev, [1]*X_dev.shape[0])
print("Baseline Score1:", accuracy_baseline1)
print("Baseline Score2:", accuracy_baseline2)
# Out:
# Baseline Score1: 0.481998325425621
# Baseline Score2: 0.5180016745743791

# %%
from sklearn import linear_model, neighbors, tree, svm, ensemble
from xgboost import XGBClassifier
# Algorithms
algorithms = []
algorithms.append(('lr', linear_model.LogisticRegression()))
algorithms.append(('sgd', linear_model.SGDClassifier()))
# algorithms.append(('knn1', neighbors.KNeighborsClassifier(n_neighbors=1))) # GOOD
# algorithms.append(('knn3', neighbors.KNeighborsClassifier(n_neighbors=3)))
# algorithms.append(('knn5', neighbors.KNeighborsClassifier(n_neighbors=5)))
# algorithms.append(('knn7', neighbors.KNeighborsClassifier(n_neighbors=7)))
# algorithms.append(('knn11', neighbors.KNeighborsClassifier(n_neighbors=11)))
algorithms.append(('dt', tree.DecisionTreeClassifier())) # EQUALLY GOOD!  GOOD INTERPRETABILITY
# algorithms.append(svm.SVC(kernel='linear')) Slow and low score
# algorithms.append(svm.SVC(kernel='poly'))
# algorithms.append(svm.SVC(kernel='rbf'))
# algorithms.append(svm.SVC(kernel='sigmoid'))
algorithms.append(('xgb', XGBClassifier(learning_rate=0.1, max_depth=10, min_child_weight=13, n_estimators=40, nthread=1, subsample=0.55)))

# %%
for (name, algorithm) in algorithms:
    algorithm.fit(X_train, y_train)
    pred = algorithm.predict(X_dev)
    print(name, accuracy_score(pred, y_dev))
# Out:
# /Users/petermyers/Desktop/Code/commons3/venv/lib/python3.8/site-packages/sklearn/utils/validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# /Users/petermyers/Desktop/Code/commons3/venv/lib/python3.8/site-packages/sklearn/utils/validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# lr 0.5417248116103823
# sgd 0.5383756628523584
# dt 0.496232207647223
# ...

# %%
import matplotlib.pyplot as plt
model = linear_model.LogisticRegression(C=75)
model.fit(X_train, y_train)
pred = model.predict(X_dev)
print(accuracy_score(pred, y_dev))
importance = model.coef_
is_ = []
is2_ = []
vs = []
for i,v in zip(df.columns, list(importance.flatten())):
    i2 = 'friendly' if '.1' not in i else 'enemy'
    i = i if '.1' not in i else f'{i.replace(".1", "")}'
    print(i, v, sep='\t')
    is_.append(i)
    is2_.append(i2)
    vs.append(v)
df2 = pd.DataFrame()
df2['i'] = is_
df2['i2'] = is2_
df2['v'] = vs
df2
# Out:
# 0.5422830030700531
# Aatrox	-0.022489376302162908
# Ahri	0.12490011426286307
# Akali	-0.11873996911795565
# Alistar	-0.03643833855804717
# Amumu	0.33992820472863855
# Anivia	-0.38014617715606247
# Annie	0.01558806133204176
# Aphelios	-0.1030759671848579
# Ashe	0.007238018619342586
# Aurelion Sol	-0.008947446992456606
# Azir	-0.40669193402921705
# Bard	0.006110056390187889
# Blitzcrank	-0.017311751059824777
# Brand	0.21755464774767944
# Braum	-0.23555886176227578
# Caitlyn	0.09125142559473544
# Camille	-0.08501585550943387
# Cassiopeia	-0.22354859853476597
# Cho'Gath	-0.10642090529850841
# Corki	-0.03488321041726686
# Darius	-0.15510706649039527
# Diana	0.2698379428541305
# Dr. Mundo	0.38026223901052264
# Draven	-0.09514189226271758
# Ekko	0.08094719671096018
# Elise	-0.11370785938548364
# Evelynn	-0.18741805896999367
# Ezreal	-0.06692272401930464
# Fiddlesticks	0.27458898004024324
# Fiora	0.08081110505361051
# Fizz	-0.010842318221603408
# Galio	0.02287255552600802
# ...

# %%
from pandasql import sqldf
sqldf("""
SELECT
  i AS champion,
  AVG(CASE
    WHEN i2 = 'friendly' THEN v
    ELSE -1*v
  END) AS coefficient
FROM df
GROUP BY 1
order by 2 desc
""", locals()).to_csv("../data/output_coefficients.csv")
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# ~/Desktop/Code/commons3/venv/lib/python3.8/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1275                 if not evt_handled:
# -> 1276                     self.dialect.do_execute(
#    1277                         cursor, statement, parameters, context
#
# ~/Desktop/Code/commons3/venv/lib/python3.8/site-packages/sqlalchemy/engine/default.py in do_execute(self, cursor, statement, parameters, context)
#     607     def do_execute(self, cursor, statement, parameters, context=None):
# --> 608         cursor.execute(statement, parameters)
#     609
#
# OperationalError: no such column: i
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# ...

# %%
for i in range(1, 10):
    model = tree.DecisionTreeClassifier(max_depth=i)
    model.fit(X_train, y_train)
    pred = model.predict(X_dev)
    print(accuracy_score(pred, y_dev))
# Out:
# 0.5026514094334357
# 0.502093217973765
# 0.506279653921295
# 0.522188110521909
# 0.5258163550097683
# 0.5115824727881664
# 0.505442366731789
# 0.5126988557075077
# 0.5177225788445436

# %%
model = tree.DecisionTreeClassifier(max_depth=4)
model.fit(X, y)
# Out:
# DecisionTreeClassifier(max_depth=4)

# %%
import graphviz
import os

dot_data = tree.export_graphviz(model, out_file=None,
                      feature_names=train.drop(["target"], axis=1).columns,
                      filled=True, rounded=True,
                      special_characters=True)
graph = graphviz.Source(dot_data)
graph.render()

os.remove("Source.gv")
os.rename("Source.gv.pdf", "decision_tree.pdf")

# %%
# Start with features of count # of each 11 roles
# Predict who goes in each role
# Make features; enchanter top etc;
# Make features of win rate of matchups
# Make simulations, try which is better garen or master yi jungle
